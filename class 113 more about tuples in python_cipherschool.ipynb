# %%
mixed =  (1,2,3,4.0)
nums = (1)
words = ('word1')
print(type(mixed))
print(type(nums))
# Out:
# <class 'tuple'>
# <class 'int'>

# %%
nums = (1,)
words = ('words1',)
guitars = 'yamaha', 'baton rouge', 'taylor'
print(type(guitars))
# Out:
# <class 'tuple'>
