# %%
# compare lists
# == , is
fruits1 = ['orange', 'apple', 'pear']
fruits3 = ['orange', 'apple', 'pear']
fruits2 = ['banana', 'kiwi', 'banana', 'apple']
print(fruits1 == fruits3) # values are same
print(fruits1 is fruits3) # false
# Out:
# True
# False
