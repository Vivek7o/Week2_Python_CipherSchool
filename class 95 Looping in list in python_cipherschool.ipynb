# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi']

# for loop
for fruit in fruits:
    print(fruit)
# Out:
# orange
# apple
# pear
# banana
# kiwi

# %%
# while loop
i = 0
while i < len(fruits):
    print(fruits[i])
    i +=1
# Out:
# orange
# apple
# pear
# banana
# kiwi
