# %%
# function inside function
# greater(a,b) ---> a or b
# greater(a or b, c) --------> greatest

def new_greatest(a,b,c):
    bigger = greater(a,b)
    return greater(bigger,c)

print(new_greatest(1000,200,30))   

# kiss - keep it simple stupid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a2766d8e508d> in <module>
#       7     return greater(bigger,c)
#       8
# ----> 9 print(new_greatest(1000,200,30))
#
# <ipython-input-1-a2766d8e508d> in new_greatest(a, b, c)
#       4
#       5 def new_greatest(a,b,c):
# ----> 6     bigger = greater(a,b)
#       7     return greater(bigger,c)
#       8
#
# NameError: name 'greater' is not defined
