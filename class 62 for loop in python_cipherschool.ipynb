# %%
# i = 0
# while i <= 10:
#     print("hello world")
#     i = i +1

# for loop with range function
for i in range(10):
    print(f"hello world : {i}")
    print("this is line")
# Out:
# hello world : 0
# this is line
# hello world : 1
# this is line
# hello world : 2
# this is line
# hello world : 3
# this is line
# hello world : 4
# this is line
# hello world : 5
# this is line
# hello world : 6
# this is line
# hello world : 7
# this is line
# hello world : 8
# this is line
# hello world : 9
# this is line
