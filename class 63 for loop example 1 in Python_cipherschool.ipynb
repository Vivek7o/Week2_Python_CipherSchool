# %%
# sum from 1 to 10
#1 + 2 + 3+ 4.........10

total = 0
for i in range(1,11):
     total += i
print(total)
# Out:
# 55

# %%
n = int(input("enter the number : "))
total = 0
for i in range(1,n+1):
    total += i
print(total)
# Out:
# enter the number : 1000000
# 500000500000
