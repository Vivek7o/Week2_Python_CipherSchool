# %%
# list inside list
matrix = [[1,2,3], [4,5,6],[7,8,9]]
# 3 times ---> 3 list
# print(matrix[2])
for sublist in matrix:
    for i in sublist:
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
matrix = [[1,2,3], [4,5,6],[7,8,9]]
print(matrix[1][1])
print(matrix[0][2])
# Out:
# 5
# 3
