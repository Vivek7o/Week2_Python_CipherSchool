# %%
numbers = [1, 2, 3, 4]
print(numbers)

# %%
words = ["word1", "word2", "word3"]
print(words[:1])

# %%
mixed = [1,2,3,4,"five", "six", 2.3, None]
print(mixed)

mixed[1:] = ['three', 'four']
print(mixed)
