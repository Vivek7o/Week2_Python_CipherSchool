# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi']
# popmethod
fruits.pop(1)
print(fruits)

# %%
#delete operator
fruits = ['orange', 'apple', 'banana', 'kiwi']
del fruits[1]
print(fruits)

# %%
fruits = ['orange', 'apple', 'banana', 'kiwi']
fruitss.remove('apple')
print(fruits)

# %%
# for deta remove = pop , remove, del
# for deta add = append, extend, insert
