# %%
name = "vivek"
for i in range(len(name)):
    print(name[i])
# Out:
# v
# i
# v
# e
# k

# %%
name = "vivek"
for i in name:
    print(i)
# Out:
# v
# i
# v
# e
# k

# %%
# 1256 ---> 1+2+5+6
num = input("enter a number :")
total = 0
for i in num:
    total += int(i)
print(total)
# Out:
# enter a number :123
# 6
