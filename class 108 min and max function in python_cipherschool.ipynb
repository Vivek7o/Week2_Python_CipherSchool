# %%
# min and max fuhnction
numbers = [6,60,2]
print(min(numbers))
print(max(numbers))
# Out:
# 2
# 60

# %%
numbers = [6,60,2]
def greatest_diff(l):
    return max(l) - min(l)

print(greatest_diff(numbers))
# Out:
# 58
